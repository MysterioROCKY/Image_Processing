# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/MyDrive/Yolo5'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.2/613.2 kB 5.0 MB/s eta 0:00:00
# ...

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov5s.pt")  # build a new model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "config.yaml"), epochs=1)  # train the model
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100%|██████████| 17.7M/17.7M [00:00<00:00, 151MB/s]
# Ultralytics YOLOv8.0.167 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/Yolo5'

# %%
pwd
# Out:
# '/content'

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=/content/gdrive/MyDrive/Yolo5/data/test
# Out:
# Ultralytics YOLOv8.0.167 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# YOLOv5s summary (fused): 193 layers, 9111923 parameters, 0 gradients
#
# image 1/10 /content/gdrive/MyDrive/Yolo5/data/test/1.jpg: 448x640 (no detections), 387.0ms
# image 2/10 /content/gdrive/MyDrive/Yolo5/data/test/10.jpg: 640x448 (no detections), 638.2ms
# image 3/10 /content/gdrive/MyDrive/Yolo5/data/test/2.jpg: 640x448 (no detections), 642.1ms
# image 4/10 /content/gdrive/MyDrive/Yolo5/data/test/3.jpg: 448x640 (no detections), 375.3ms
# image 5/10 /content/gdrive/MyDrive/Yolo5/data/test/4.jpg: 640x480 (no detections), 398.4ms
# image 6/10 /content/gdrive/MyDrive/Yolo5/data/test/5.jpg: 640x512 (no detections), 432.4ms
# image 7/10 /content/gdrive/MyDrive/Yolo5/data/test/6.jpg: 448x640 (no detections), 364.3ms
# image 8/10 /content/gdrive/MyDrive/Yolo5/data/test/7.jpg: 640x640 (no detections), 539.0ms
# image 9/10 /content/gdrive/MyDrive/Yolo5/data/test/8.jpg: 576x640 (no detections), 639.8ms
# ...
